# %% [markdown]
# <a href="https://colab.research.google.com/github/sliffer28/web/blob/master/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **DataFrames**

# %%
import pandas as pd

# %%
data = {
    "name" : ['ab', 'cd', 'ef'],
    "age": [10, 20, 30],
    "score": [100, 200, 300]
}

data1 = [['abhijeet', 28,  100],
         ['Ranjan', 35, 200],
         ['Cristiano', 32, 400]]
df = pd.DataFrame(data1, columns=['Name', 'Age', 'Score'])

print(df)

file_path = '../content/Amazon.csv'
pd.read_csv(file_path)
# Out:
#         Name  Age  Score
# 0   abhijeet   28    100
# 1     Ranjan   35    200
# 2  Cristiano   32    400
# <ipython-input-16-0d99b88ff332>:15: DtypeWarning: Columns (21,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   pd.read_csv(file_path)
#        index             Order ID      Date                        Status  \
# 0          0  405-8078784-5731545  04-30-22                     Cancelled
# 1          1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2          2  404-0687676-7273146  04-30-22                       Shipped
# 3          3  403-9615377-8133951  04-30-22                     Cancelled
# 4          4  407-1069790-7240320  04-30-22                       Shipped
# ...      ...                  ...       ...                           ...
# 94426  94426  407-6203656-6522762  06-26-22                       Shipped
# 94427  94427  402-6839959-5605921  06-26-22           Shipped - Picked Up
# ...

# %% [markdown]
# ## **Looking at dataFrames**

# %%
file_path = '../content/Amazon.csv'
ef = pd.read_csv(file_path)
# Out:
# <ipython-input-33-66b5d84524b2>:2: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   ef = pd.read_csv(file_path)

# %% [markdown]
# ### **Head/Tails method**
# Head - this method shows the top rows
# Tail -  this method shows bottom rows

# %%
ef.head()
# Out:
#    index             Order ID      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  04-30-22                       Shipped
# 3      3  403-9615377-8133951  04-30-22                     Cancelled
# 4      4  407-1069790-7240320  04-30-22                       Shipped
#
#   Fulfilment Sales Channel  ship-service-level    Style              SKU  \
# 0   Merchant      Amazon.in           Standard   SET389   SET389-KR-NP-S
# 1   Merchant      Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL
# 2     Amazon      Amazon.in          Expedited  JNE3371    JNE3371-KR-XL
# 3   Merchant      Amazon.in           Standard    J0341       J0341-DR-L
# 4     Amazon      Amazon.in          Expedited  JNE3671  JNE3671-TU-XXXL
#
#         Category  ... currency  Amount    ship-city   ship-state  \
# ...

# %%
ef.tail()
# Out:
#          index             Order ID      Date   Status Fulfilment  \
# 128970  128970  406-6001380-7673107  05-31-22  Shipped     Amazon
# 128971  128971  402-9551604-7544318  05-31-22  Shipped     Amazon
# 128972  128972  407-9547469-3152358  05-31-22  Shipped     Amazon
# 128973  128973  402-6184140-0545956  05-31-22  Shipped     Amazon
# 128974  128974  408-7436540-8728312  05-31-22  Shipped     Amazon
#
#        Sales Channel  ship-service-level    Style             SKU  \
# 128970      Amazon.in          Expedited  JNE3697   JNE3697-KR-XL
# 128971      Amazon.in          Expedited   SET401  SET401-KR-NP-M
# 128972      Amazon.in          Expedited    J0157    J0157-DR-XXL
# 128973      Amazon.in          Expedited    J0012    J0012-SKD-XS
# 128974      Amazon.in          Expedited    J0003     J0003-SET-S
#
#              Category  ... currency  Amount  ship-city    ship-state  \
# 128970          kurta  ...      INR   517.0  HYDERABAD     TELANGANA
# ...

# %% [markdown]
# ### **Descritive Statistics**

# %%
ef.describe()
# Out:
#                index            Qty         Amount  ship-postal-code
# count  128975.000000  128975.000000  121180.000000     128942.000000
# mean    64487.000000       0.904431     648.561465     463966.236509
# std     37232.019822       0.313354     281.211687     191476.764941
# min         0.000000       0.000000       0.000000     110001.000000
# 25%     32243.500000       1.000000     449.000000     382421.000000
# 50%     64487.000000       1.000000     605.000000     500033.000000
# 75%     96730.500000       1.000000     788.000000     600024.000000
# max    128974.000000      15.000000    5584.000000     989898.000000

# %%
ef.count()
# Out:
# index                 128975
# Order ID              128975
# Date                  128975
# Status                128975
# Fulfilment            128975
# Sales Channel         128975
# ship-service-level    128975
# Style                 128975
# SKU                   128975
# Category              128975
# Size                  128975
# ASIN                  128975
# Courier Status        122103
# Qty                   128975
# currency              121180
# Amount                121180
# ship-city             128942
# ship-state            128942
# ship-postal-code      128942
# ship-country          128942
# promotion-ids          79822
# B2B                   128975
# fulfilled-by           39277
# Unnamed: 22            79925
# dtype: int64

# %% [markdown]
# ### **Selecting Columns**

# %%
ef.columns
# Out:
# Index(['index', 'Order ID', 'Date', 'Status', 'Fulfilment', 'Sales Channel ',
#        'ship-service-level', 'Style', 'SKU', 'Category', 'Size', 'ASIN',
#        'Courier Status', 'Qty', 'currency', 'Amount', 'ship-city',
#        'ship-state', 'ship-postal-code', 'ship-country', 'promotion-ids',
#        'B2B', 'fulfilled-by', 'Unnamed: 22'],
#       dtype='object')

# %%
ef[['Order ID', 'Amount', 'Category']]
# Out:
#                    Order ID   Amount       Category
# 0       405-8078784-5731545   647.62            Set
# 1       171-9198151-1101146   406.00          kurta
# 2       404-0687676-7273146   329.00          kurta
# 3       403-9615377-8133951   753.33  Western Dress
# 4       407-1069790-7240320   574.00            Top
# ...                     ...      ...            ...
# 128970  406-6001380-7673107   517.00          kurta
# 128971  402-9551604-7544318   999.00            Set
# 128972  407-9547469-3152358   690.00  Western Dress
# 128973  402-6184140-0545956  1199.00            Set
# 128974  408-7436540-8728312   696.00            Set
#
# [128975 rows x 3 columns]
# ...
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Amount'].plot(kind='hist', bins=20, title='Amount')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...

# %%
ef.Amount
# Out:
# 0          647.62
# 1          406.00
# 2          329.00
# 3          753.33
# 4          574.00
#            ...
# 128970     517.00
# 128971     999.00
# 128972     690.00
# 128973    1199.00
# 128974     696.00
# Name: Amount, Length: 128975, dtype: float64

# %% [markdown]
# ### **Selectiong Columns and Rows**

# %%
ef.iloc[3:10]
# Out:
#    index             Order ID      Date                        Status  \
# 3      3  403-9615377-8133951  04-30-22                     Cancelled
# 4      4  407-1069790-7240320  04-30-22                       Shipped
# 5      5  404-1490984-4578765  04-30-22                       Shipped
# 6      6  408-5748499-6859555  04-30-22                       Shipped
# 7      7  406-7807733-3785945  04-30-22  Shipped - Delivered to Buyer
# 8      8  407-5443024-5233168  04-30-22                     Cancelled
# 9      9  402-4393761-0311520  04-30-22                       Shipped
#
#   Fulfilment Sales Channel  ship-service-level    Style                  SKU  \
# 3   Merchant      Amazon.in           Standard    J0341           J0341-DR-L
# 4     Amazon      Amazon.in          Expedited  JNE3671      JNE3671-TU-XXXL
# 5     Amazon      Amazon.in          Expedited   SET264      SET264-KR-NP-XL
# 6     Amazon      Amazon.in          Expedited    J0095          J0095-SET-L
# ...

# %%
ef.iloc[3:10, 3:5]
# Out:
#                          Status Fulfilment
# 3                     Cancelled   Merchant
# 4                       Shipped     Amazon
# 5                       Shipped     Amazon
# 6                       Shipped     Amazon
# 7  Shipped - Delivered to Buyer   Merchant
# 8                     Cancelled     Amazon
# 9                       Shipped     Amazon

# %%
ef.head()

ef.loc[1:10]
# Out:
#     index             Order ID      Date                        Status  \
# 1       1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2       2  404-0687676-7273146  04-30-22                       Shipped
# 3       3  403-9615377-8133951  04-30-22                     Cancelled
# 4       4  407-1069790-7240320  04-30-22                       Shipped
# 5       5  404-1490984-4578765  04-30-22                       Shipped
# 6       6  408-5748499-6859555  04-30-22                       Shipped
# 7       7  406-7807733-3785945  04-30-22  Shipped - Delivered to Buyer
# 8       8  407-5443024-5233168  04-30-22                     Cancelled
# 9       9  402-4393761-0311520  04-30-22                       Shipped
# 10     10  407-5633625-6970741  04-30-22                       Shipped
#
#    Fulfilment Sales Channel  ship-service-level    Style                  SKU  \
# 1    Merchant      Amazon.in           Standard  JNE3781      JNE3781-KR-XXXL
# ...

# %%
ef.loc[1:3, ['Order ID', 'SKU']]
# Out:
#               Order ID              SKU
# 1  171-9198151-1101146  JNE3781-KR-XXXL
# 2  404-0687676-7273146    JNE3371-KR-XL
# 3  403-9615377-8133951       J0341-DR-L

# %% [markdown]
# ## **Selecting DataFrame Data**

# %% [markdown]
# ### **Boolean Mask**

# %%
mask = [False for _ in range(len(ef))]
mask[2:5] = [True] * 3
mask
# Out:
# [False,
#  False,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
# ...

# %%
ef.loc[mask]
# Out:
#    index             Order ID      Date     Status Fulfilment Sales Channel   \
# 2      2  404-0687676-7273146  04-30-22    Shipped     Amazon      Amazon.in
# 3      3  403-9615377-8133951  04-30-22  Cancelled   Merchant      Amazon.in
# 4      4  407-1069790-7240320  04-30-22    Shipped     Amazon      Amazon.in
#
#   ship-service-level    Style              SKU       Category  ... currency  \
# 2          Expedited  JNE3371    JNE3371-KR-XL          kurta  ...      INR
# 3           Standard    J0341       J0341-DR-L  Western Dress  ...      INR
# 4          Expedited  JNE3671  JNE3671-TU-XXXL            Top  ...      INR
#
#    Amount ship-city   ship-state ship-postal-code  ship-country  \
# 2  329.00   CHENNAI  MAHARASHTRA         410210.0            IN
# 3  753.33   CHENNAI   PUDUCHERRY         605008.0            IN
# 4  574.00   CHENNAI   TAMIL NADU         600073.0            IN
#
#                                   promotion-ids    B2B  fulfilled-by  \
# ...

# %% [markdown]
# ### **Creating mask using comparison operator**

# %%
mask = ef.loc[:, 'ship-city'] == 'CHENNAI'
ef[mask]
# Out:
#          index             Order ID      Date                        Status  \
# 0            0  405-8078784-5731545  04-30-22                     Cancelled
# 1            1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2            2  404-0687676-7273146  04-30-22                       Shipped
# 3            3  403-9615377-8133951  04-30-22                     Cancelled
# 4            4  407-1069790-7240320  04-30-22                       Shipped
# ...        ...                  ...       ...                           ...
# 128970  128970  406-6001380-7673107  05-31-22                       Shipped
# 128971  128971  402-9551604-7544318  05-31-22                       Shipped
# 128972  128972  407-9547469-3152358  05-31-22                       Shipped
# 128973  128973  402-6184140-0545956  05-31-22                       Shipped
# 128974  128974  408-7436540-8728312  05-31-22                       Shipped
#
# ...

# %%
ef.loc[mask]
# Out:
#          index             Order ID      Date                        Status  \
# 0            0  405-8078784-5731545  04-30-22                     Cancelled
# 1            1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2            2  404-0687676-7273146  04-30-22                       Shipped
# 3            3  403-9615377-8133951  04-30-22                     Cancelled
# 4            4  407-1069790-7240320  04-30-22                       Shipped
# ...        ...                  ...       ...                           ...
# 128970  128970  406-6001380-7673107  05-31-22                       Shipped
# 128971  128971  402-9551604-7544318  05-31-22                       Shipped
# 128972  128972  407-9547469-3152358  05-31-22                       Shipped
# 128973  128973  402-6184140-0545956  05-31-22                       Shipped
# 128974  128974  408-7436540-8728312  05-31-22                       Shipped
#
# ...

# %% [markdown]
# ### **Pandas Boolean Operator**

# %%
ef.describe
# Out:
#                index            Qty         Amount  ship-postal-code
# count  128975.000000  128975.000000  121180.000000     128942.000000
# mean    64487.000000       0.904431     648.561465     463966.236509
# std     37232.019822       0.313354     281.211687     191476.764941
# min         0.000000       0.000000       0.000000     110001.000000
# 25%     32243.500000       1.000000     449.000000     382421.000000
# 50%     64487.000000       1.000000     605.000000     500033.000000
# 75%     96730.500000       1.000000     788.000000     600024.000000
# max    128974.000000      15.000000    5584.000000     989898.000000

# %%
mask = (ef.loc[:, 'index'].astype(int) < 500) & (ef.loc[:, 'Amount'] < 100)
ef.loc[mask]
# Out:
#      index             Order ID      Date                        Status  \
# 212    212  408-4547464-4180323  04-30-22  Shipped - Delivered to Buyer
# 374    374  408-5020509-5674715  04-30-22  Shipped - Returned to Seller
# 385    385  408-3137526-3167563  04-30-22                       Shipped
# 388    388  408-7971979-8745937  04-30-22  Shipped - Delivered to Buyer
# 392    392  408-0912805-7526753  04-30-22                       Shipped
# 436    436  408-6466311-6949931  04-30-22                       Shipped
# 441    441  408-6732772-4525113  04-30-22  Shipped - Delivered to Buyer
# 446    446  408-7937211-8974712  04-30-22                       Shipped
# 449    449  408-6348199-2089932  04-30-22                       Shipped
#
#     Fulfilment Sales Channel  ship-service-level    Style               SKU  \
# 212   Merchant      Amazon.in           Standard  JNE3568    JNE3568-KR-XXL
# 374   Merchant      Amazon.in           Standard  JNE3798      JNE3798-KR-M
# ...

# %% [markdown]
# ### **Creating new column**

# %%
ef.loc[:, 'amount_tax'] = ef.loc[:, 'Amount'] + 0.18 * ef.loc[:, 'Amount']

# %%
ef.head()
# Out:
#    index             Order ID      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  04-30-22                       Shipped
# 3      3  403-9615377-8133951  04-30-22                     Cancelled
# 4      4  407-1069790-7240320  04-30-22                       Shipped
#
#   Fulfilment Sales Channel  ship-service-level    Style              SKU  \
# 0   Merchant      Amazon.in           Standard   SET389   SET389-KR-NP-S
# 1   Merchant      Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL
# 2     Amazon      Amazon.in          Expedited  JNE3371    JNE3371-KR-XL
# 3   Merchant      Amazon.in           Standard    J0341       J0341-DR-L
# 4     Amazon      Amazon.in          Expedited  JNE3671  JNE3671-TU-XXXL
#
#         Category  ...  Amount ship-city   ship-state  ship-postal-code  \
# ...

# %% [markdown]
# # **Manupulating DataFrames**

# %%
import pandas as pd
data = {'first': ['Carl', 'Francis', 'Sam'],
        'last':  ['Po',   'Nyguen',  'Smith'],
        'age':   ['32',   '45',      '22']}
clients = pd.DataFrame(data)
clients
# Out:
#      first    last age
# 0     Carl      Po  32
# 1  Francis  Nyguen  45
# 2      Sam   Smith  22

# %% [markdown]
# ## **Renaming**

# %%
clients.rename(columns = {'first' : 'First Name'}, inplace = True)

# %%
clients.rename(index = {0 : 'a', 1 : 'b', 2 : 'c'}, inplace = True)

# %%
clients
# Out:
#   First Name    last age
# a       Carl      Po  32
# b    Francis  Nyguen  45
# c        Sam   Smith  22

# %%
clients.reset_index(inplace = True)
clients
# Out:
#    level_0 index First Name    last age
# 0        0     a       Carl      Po  32
# 1        1     b    Francis  Nyguen  45
# 2        2     c        Sam   Smith  22

# %% [markdown]
# ## **Dropping**

# %%
clients.drop(columns = 'First Name')
# Out:
#    level_0 index    last age
# 0        0     a      Po  32
# 1        1     b  Nyguen  45
# 2        2     c   Smith  22

# %%
clients.drop(index = 0)
# Out:
#    level_0 index First Name    last age
# 1        1     b    Francis  Nyguen  45
# 2        2     c        Sam   Smith  22

# %% [markdown]
# ## **SetType**

# %%
clients.age
# Out:
# 0    32
# 1    45
# 2    22
# Name: age, dtype: object

# %%
clients.age.astype(int)
# Out:
# 0    32
# 1    45
# 2    22
# Name: age, dtype: int64

# %% [markdown]
# # **Updating DataFrames Data**

# %%
import pandas as pd
data = {'first': ['Carl', 'Francis', 'Sam'],
        'last':  ['Po',   'Nyguen',  'Smith'],
        'age':   ['32',   '45',      '22'],
        'CH_count':[12,  14, 39]}
clients = pd.DataFrame(data)
clients
# Out:
#      first    last age  CH_count
# 0     Carl      Po  32        12
# 1  Francis  Nyguen  45        14
# 2      Sam   Smith  22        39

# %% [markdown]
# ## **Adding Rows**

# %%
new_data = {'first':['Sue', 'Boya'],
            'last':['Rankler', 'Maple'],
            'age':[93, 12],
            'CH_count':[22, 1]}
new_clients = pd.DataFrame(new_data)
new_clients
# Out:
#   first     last  age  CH_count
# 0   Sue  Rankler   93        22
# 1  Boya    Maple   12         1

# %%
clients = pd.concat([clients, new_clients])
clients

#.append() is removed from pandas for 2.0 and higher version so we use .concat() to join two tables
# Out:
#      first     last age  CH_count
# 0     Carl       Po  32        12
# 1  Francis   Nyguen  45        14
# 2      Sam    Smith  22        39
# 0      Sue  Rankler  93        22
# 1     Boya    Maple  12         1

# %% [markdown]
# ## **Setting specific Value**

# %%
clients.loc[1, 'first'] = 'Bob'
clients
# Out:
#   first    last age  CH_count
# 0  Carl      Po  32        12
# 1   Bob  Nyguen  45        14
# 2   Sam   Smith  22        39

# %%
clients.loc[0:1, 'CH_count'] = 10
clients
# Out:
#   first    last age  CH_count
# 0  Carl      Po  32        10
# 1   Bob  Nyguen  45        10
# 2   Sam   Smith  22        39

# %% [markdown]
# ##**MATH Operations**

# %%
clients.CH_count += 1
clients
# Out:
#   first    last age  CH_count
# 0  Carl      Po  32        11
# 1   Bob  Nyguen  45        11
# 2   Sam   Smith  22        40

# %% [markdown]
# ##**Replace**

# %%
clients.replace(11, 99)
# Out:
#   first    last age  CH_count
# 0  Carl      Po  32        99
# 1   Bob  Nyguen  45        99
# 2   Sam   Smith  22        40
